# %%
# To mount drive where files are stored
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# To check the content of the xml file
import gzip

file_path = "/content/drive/MyDrive/DISCOGS/discogs_20250601_releases.xml.gz"

with gzip.open(file_path, 'rt', encoding='utf-8') as f:
    for i in range(20):
        print(f.readline())
# Out:
# <releases>
#
# <release id="1" status="Accepted"><artists><artist><id>1</id><name>The Persuader</name></artist></artists><title>Stockholm</title><labels><label name="Svek" catno="SK032" id="5"/></labels><extraartists><artist><id>507025</id><name>George Cutmaster General</name><anv>G Phrupmastergeneral</anv><role>Lacquer Cut By</role></artist><artist><id>239</id><name>Jesper Dahlbäck</name><role>Written-By [All Tracks By]</role></artist></extraartists><formats><format name="Vinyl" qty="2" text=""><descriptions><description>12"</description><description>33 ⅓ RPM</description></descriptions></format></formats><genres><genre>Electronic</genre></genres><styles><style>Deep House</style></styles><country>Sweden</country><released>1999-03-00</released><notes>The song titles are the names of six Stockholm districts.
#
#
#
# Title on labels: - Stockholm -
#
#
#
# [Labels:]
#
# Recorded at the Globe studio, Stockholm
#
#
#
# Fax: +46 8 679 64 53</notes><data_quality>Needs Vote</data_quality><master_id is_main_release="true">1660109</master_id><tracklist><track><position>A</position><title>Östermalm</title><duration>4:45</duration></track><track><position>B1</position><title>Vasastaden</title><duration>6:11</duration></track><track><position>B2</position><title>Kungsholmen</title><duration>2:49</duration></track><track><position>C1</position><title>Södermalm</title><duration>5:38</duration></track><track><position>C2</position><title>Norrmalm</title><duration>4:52</duration></track><track><position>D</position><title>Gamla Stan</title><duration>5:16</duration></track></tracklist><identifiers><identifier type="Matrix / Runout" description="A-side runout" value="MPO SK 032 A1 G PHRUPMASTERGENERAL T2T LONDON"/><identifier type="Matrix / Runout" description="B-side runout" value="MPO SK 032 B1"/><identifier type="Matrix / Runout" description="C-side runout" value="MPO SK 032 C1"/><identifier type="Matrix / Runout" description="D-side runout" value="MPO SK 032 D1"/></identifiers><videos><video src="https://www.youtube.com/watch?v=afMHNll9EVM" duration="325" embed="true"><title>The Persuader - Gamla Stan</title><description>https://www.discogs.com/The-Persuader-Stockholm/release/1
#
#
#
# The Persuader - Gamla Stan</description></video><video src="https://www.youtube.com/watch?v=XExCZfMCXdo" duration="175" embed="true"><title>The Persuader - Kungsholmen</title><description>https://www.discogs.com/The-Persuader-Stockholm/release/1
#
#
#
# The Persuader - Kungsholmen</description></video><video src="https://www.youtube.com/watch?v=WDZqiENap_U" duration="340" embed="true"><title>The Persuader - Södermalm</title><description>https://www.discogs.com/The-Persuader-Stockholm/release/1
#
#
#
# The Persuader - Södermalm</description></video><video src="https://www.youtube.com/watch?v=EBBHR3EMN50" duration="300" embed="true"><title>The Persuader - Norrmalm</title><description>https://www.discogs.com/The-Persuader-Stockholm/release/1
#
#
#
# The Persuader - Norrmalm</description></video><video src="https://www.youtube.com/watch?v=Cawyll0pOI4" duration="375" embed="true"><title>The Persuader - Vasastaden</title><description>https://www.discogs.com/The-Persuader-Stockholm/release/1
#
#
#
# The Persuader - Vasastaden</description></video><video src="https://www.youtube.com/watch?v=MpmbntGDyNE" duration="295" embed="true"><title>The Persuader - Östermalm</title><description>https://www.discogs.com/The-Persuader-Stockholm/release/1&#13;
#
# &#13;

# %%
# To extract the desired data frame from xml file filtering for House Music and keeping only desired fields
import xml.etree.ElementTree as ET
import pandas as pd
import csv


# File paths
input_file = '/content/drive/MyDrive/DISCOGS/discogs_20250601_releases.xml.gz'
output_file = '/content/drive/MyDrive/DISCOGS/house_music_releases_02.csv'

# Initialize CSV with header
columns = ['id', 'title', 'year', 'country', 'styles', 'genres', 'label']
with open(output_file, mode='w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=columns)
    writer.writeheader()

# Stream and parse the XML
with gzip.open(input_file, 'rb') as f:
    context = ET.iterparse(f, events=('end',))
    for i, (event, elem) in enumerate(context):
        if elem.tag == 'release':
            try:
                genre_tags = [g.text for g in elem.findall('./genres/genre')]
                style_tags = [s.text for s in elem.findall('./styles/style')]

                if 'Electronic' in genre_tags and any('House' in (s or '') for s in style_tags):
                    release_id = elem.attrib.get('id')
                    title = elem.findtext('title')
                    year = elem.findtext('released')
                    country = elem.findtext('country')
                    styles = ', '.join(style_tags)
                    genres = ', '.join(genre_tags)
                    label_elem = elem.find('./labels/label')
                    label = label_elem.attrib.get('name') if label_elem is not None else None

                    # Append row to CSV
                    with open(output_file, mode='a', newline='', encoding='utf-8') as out_f:
                        writer = csv.DictWriter(out_f, fieldnames=columns)
                        writer.writerow({
                            'id': release_id,
                            'title': title,
                            'year': year,
                            'country': country,
                            'styles': styles,
                            'genres': genres,
                            'label': label
                        })
            except Exception as e:
                print(f"⚠️ Skipping record due to error: {e}")
            finally:
                elem.clear()

        if i % 500 == 0:
            print(f"Processed {i} records...")

print("Extraction complete. File saved to Google Drive.")
# Out:
# ✅ Processed 0 records...
# ✅ Processed 500 records...
# ✅ Processed 1000 records...
# ✅ Processed 1500 records...
# ✅ Processed 2000 records...
# ✅ Processed 2500 records...
# ✅ Processed 3000 records...
# ✅ Processed 3500 records...
# ✅ Processed 4000 records...
# ✅ Processed 4500 records...
# ✅ Processed 5000 records...
# ✅ Processed 5500 records...
# ✅ Processed 6000 records...
# ✅ Processed 6500 records...
# ✅ Processed 7000 records...
# ✅ Processed 7500 records...
# ✅ Processed 8000 records...
# ✅ Processed 8500 records...
# ✅ Processed 9000 records...
# ✅ Processed 9500 records...
# ✅ Processed 10000 records...
# ✅ Processed 10500 records...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4-1831236665.py in <cell line: 0>()
#      35
#      36                     # ✅ Append row to CSV
# ---> 37                     with open(output_file, mode='a', newline='', encoding='utf-8') as out_f:
#      38                         writer = csv.DictWriter(out_f, fieldnames=columns)
#      39                         writer.writerow({
#
# KeyboardInterrupt:

# %%
# To extract Master Releases data fram from xml file

# File paths
input_file = '/content/drive/MyDrive/DISCOGS/discogs_20250601_masters.xml.gz'
output_file = '/content/drive/MyDrive/DISCOGS/master_releases.csv'

# Initialize CSV with header
columns = ['id', 'title', 'year', 'genres', 'styles']
with open(output_file, mode='w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=columns)
    writer.writeheader()

# Stream and parse the XML
with gzip.open(input_file, 'rb') as f:
    context = ET.iterparse(f, events=('end',))
    for i, (event, elem) in enumerate(context):
        if elem.tag == 'master':
            try:
                genre_tags = [g.text for g in elem.findall('./genres/genre')]
                style_tags = [s.text for s in elem.findall('./styles/style')]

                # Filter for House music
                if 'Electronic' in genre_tags and any('House' in (s or '') for s in style_tags):
                    master_id = elem.attrib.get('id')
                    title = elem.findtext('title')
                    year = elem.findtext('year')
                    genres = ', '.join(genre_tags)
                    styles = ', '.join(style_tags)

                    # Append row to CSV
                    with open(output_file, mode='a', newline='', encoding='utf-8') as out_f:
                        writer = csv.DictWriter(out_f, fieldnames=columns)
                        writer.writerow({
                            'id': master_id,
                            'title': title,
                            'year': year,
                            'genres': genres,
                            'styles': styles
                        })
            except Exception as e:
                print(f"⚠️ Skipping record due to error: {e}")
            finally:
                elem.clear()

        if i % 500 == 0:
            print(f"Processed {i} records...")

print("Extraction complete. File saved to Google Drive.")
# Out:
# Processed 0 records...
# Processed 500 records...
# Processed 1000 records...
# Processed 1500 records...
# Processed 2000 records...
# Processed 2500 records...
# Processed 3000 records...
# Processed 3500 records...
# Processed 4000 records...
# Processed 4500 records...
# Processed 5000 records...
# Processed 5500 records...
# Processed 6000 records...
# Processed 6500 records...
# Processed 7000 records...
# Processed 7500 records...
# Processed 8000 records...
# Processed 8500 records...
# Processed 9000 records...
# Processed 9500 records...
# Processed 10000 records...
# Processed 10500 records...
# Processed 11000 records...
# Processed 11500 records...
# Processed 12000 records...
# Processed 12500 records...
# Processed 13000 records...
# Processed 13500 records...
# Processed 14000 records...
# Processed 14500 records...
# Processed 15000 records...
# Processed 15500 records...
# Processed 16000 records...
# Processed 16500 records...
# Processed 17000 records...
# Processed 17500 records...
# Processed 18000 records...
# Processed 18500 records...
# Processed 19000 records...
# Processed 19500 records...
# Processed 20000 records...
# Processed 20500 records...
# Processed 21000 records...
# Processed 21500 records...
# Processed 22000 records...
# Processed 22500 records...
# Processed 23000 records...
# Processed 23500 records...
# Processed 24000 records...
# Processed 24500 records...
# Processed 25000 records...
# Processed 25500 records...
# Processed 26000 records...
# Processed 26500 records...
# Processed 27000 records...
# Processed 27500 records...
# Processed 28000 records...
# Processed 28500 records...
# Processed 29000 records...
# Processed 29500 records...
# Processed 30000 records...
# Processed 30500 records...
# Processed 31000 records...
# Processed 31500 records...
# Processed 32000 records...
# Processed 32500 records...
# Processed 33000 records...
# Processed 33500 records...
# Processed 34000 records...
# Processed 34500 records...
# Processed 35000 records...
# Processed 35500 records...
# Processed 36000 records...
# Processed 36500 records...
# Processed 37000 records...
# Processed 37500 records...
# Processed 38000 records...
# Processed 38500 records...
# Processed 39000 records...
# Processed 39500 records...
# Processed 40000 records...
# Processed 40500 records...
# Processed 41000 records...
# Processed 41500 records...
# Processed 42000 records...
# Processed 42500 records...
# Processed 43000 records...
# Processed 43500 records...
# Processed 44000 records...
# Processed 44500 records...
# Processed 45000 records...
# Processed 45500 records...
# Processed 46000 records...
# Processed 46500 records...
# Processed 47000 records...
# Processed 47500 records...
# Processed 48000 records...
# Processed 48500 records...
# Processed 49000 records...
# Processed 49500 records...
# Processed 50000 records...
# Processed 50500 records...
# Processed 51000 records...
# Processed 51500 records...
# Processed 52000 records...
# Processed 52500 records...
# Processed 53000 records...
# Processed 53500 records...
# Processed 54000 records...
# Processed 54500 records...
# Processed 55000 records...
# Processed 55500 records...
# Processed 56000 records...
# Processed 56500 records...
# Processed 57000 records...
# Processed 57500 records...
# Processed 58000 records...
# Processed 58500 records...
# Processed 59000 records...
# Processed 59500 records...
# Processed 60000 records...
# Processed 60500 records...
# Processed 61000 records...
# Processed 61500 records...
# Processed 62000 records...
# Processed 62500 records...
# Processed 63000 records...
# Processed 63500 records...
# Processed 64000 records...
# Processed 64500 records...
# Processed 65000 records...
# Processed 65500 records...
# Processed 66000 records...
# Processed 66500 records...
# Processed 67000 records...
# Processed 67500 records...
# Processed 68000 records...
# Processed 68500 records...
# Processed 69000 records...
# Processed 69500 records...
# Processed 70000 records...
# Processed 70500 records...
# Processed 71000 records...
# Processed 71500 records...
# Processed 72000 records...
# Processed 72500 records...
# Processed 73000 records...
# Processed 73500 records...
# Processed 74000 records...
# Processed 74500 records...
# Processed 75000 records...
# Processed 75500 records...
# Processed 76000 records...
# Processed 76500 records...
# Processed 77000 records...
# Processed 77500 records...
# Processed 78000 records...
# Processed 78500 records...
# Processed 79000 records...
# Processed 79500 records...
# Processed 80000 records...
# Processed 80500 records...
# Processed 81000 records...
# Processed 81500 records...
# Processed 82000 records...
# Processed 82500 records...
# Processed 83000 records...
# Processed 83500 records...
# Processed 84000 records...
# Processed 84500 records...
# Processed 85000 records...
# Processed 85500 records...
# Processed 86000 records...
# Processed 86500 records...
# Processed 87000 records...
# Processed 87500 records...
# Processed 88000 records...
# Processed 88500 records...
# Processed 89000 records...
# Processed 89500 records...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-5-2673383502.py in <cell line: 0>()
#      29
#      30                     # Append row to CSV
# ---> 31                     with open(output_file, mode='a', newline='', encoding='utf-8') as out_f:
#      32                         writer = csv.DictWriter(out_f, fieldnames=columns)
#      33                         writer.writerow({
#
# KeyboardInterrupt:
